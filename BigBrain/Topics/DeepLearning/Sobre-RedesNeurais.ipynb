# %% [markdown]
# # Fontes
#
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.asimovinstitute.org/neural-network-zoo/

# %% [markdown]
#  Por exemplo, no aplicativo de imóveis que vimos no vídeo anterior, usamos uma arquitetura padrão universalizada de rede neural, certo? Talvez para o setor imobiliário e publicidade on-line podem ser relativamente rede neural padrão, como a que vimos.
# Reproduza o vídeo começando em :3:13 e siga a transcrição3:13
# Para aplicativos de imagens, geralmente usaremos redes neurais convolucionais, abreviadas como CNNs.
# Reproduza o vídeo começando em :3:21 e siga a transcrição3:21
# E para dados de sequência. Assim, por exemplo, o áudio tem uma componente temporal, certo? Áudio é descartado ao longo do tempo, então o áudio é representado mais naturalmente como séries unidimensionais de tempo ou como uma sequência temporal unidimensional. E então para dados de sequência, você frequentemente usa um RNN, que é uma Rede Neural Recorrente. Linguagem, Inglês e Chinês, os alfabetos ou as palavras vêm uma de cada vez. Assim, linguagem também é mais naturalmente representada como dados de sequência. Bem como versões mais complexas de RNNs são geralmente usadas para tais aplicativos. E, para aplicativos mais complexos, como veículos autoconduzidos, onde temos uma imagem, isso sugere mais o uso de estrutura CNN , rede neural convolucional, e informações de radar, estas já são algo um pouco diferente. Você poderia com uma rede mais personalizada, ou algo mais complexo, como uma arquitetura de rede neural híbrida.
